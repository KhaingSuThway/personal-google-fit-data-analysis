# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Hey there! 🌟 Looks like we're getting started with a cool data analysis project! Let me walk you through the libraries we're bringing on board:
#
# __os__: This little guy helps us interact with the operating system. It's like our secret agent, allowing us to do all sorts of cool stuff with directories and files. Although we imported it, we won't be using it in this snippet, but hey, it's part of the squad!
#
# __Numpy__: This library is like the mathematical genius in our team! It's all about handling big datasets and performing super-fast mathematical operations. We've given it the nickname "np," so we can call on it with just two letters. It's going to make crunching numbers a breeze!
#
# __Pandas__: Meet our data wizard, "Pandas"! 🧙‍♂️ It knows all the tricks for manipulating and analyzing data like a pro. We're going to call it "pd" to keep things snappy and easy-breezy. With Pandas by our side, we'll tame any dataset that comes our way!
#
# __Seaborn and Matplotlib__: These two are our dynamic duo for data visualization! 🌟 Seaborn is like the stylish fashionista that knows how to create eye-catching plots effortlessly. It builds on top of Matplotlib, which is the backbone of data visualization in Python. We've brought them both on board because they complement each other perfectly. Seaborn adds that extra touch of elegance to our plots, while Matplotlib gives us the flexibility to fine-tune every detail.
#
# __Matplotlib.pyplot__: Give it up for the legendary "Matplotlib" - the Picasso of data visualization! 🎨 It can whip up all sorts of beautiful plots, static or interactive. We'll call it "plt," our trusty artist, to keep things artsy and fun.

# %%
fitDataFrame=pd.read_csv("Daily activity metrics.csv")

# %% [markdown]
# Nice! Looks like we've loaded the data from  __"Daily activity metrics.csv"__ file into a DataFrame called **fitDataFrame. 📊
#
# By using the **pd.read_csv()** function from the Pandas library, we've efficiently read the data from the CSV file and converted it into a tabular format - **a DataFrame!** This DataFrame is like a structured spreadsheet that allows us to easily organize, manipulate, and analyze the data.
#
# Now, we can dive into the exciting world of data exploration and analysis with the fitDataFrame. Whether it's plotting trends, calculating statistics, or discovering valuable insights, our data journey is just getting started!
#
# Let's together keep up the great work, and have fun uncovering the hidden gems within our Google Fit data! 🌟🚀🔍

# %%
fitDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        401 non-null    object
#  1   Move Minutes count          325 non-null    float64
#  2   Calories (kcal)             400 non-null    float64
#  3   Distance (m)                341 non-null    float64
#  4   Heart Points                208 non-null    float64
#  5   Heart Minutes               208 non-null    float64
#  6   Average heart rate (bpm)    58 non-null     float64
#  7   Max heart rate (bpm)        58 non-null     float64
#  8   Min heart rate (bpm)        58 non-null     float64
#  9   Low latitude (deg)          98 non-null     float64
#  10  Low longitude (deg)         98 non-null     float64
#  11  High latitude (deg)         98 non-null     float64
#  12  High longitude (deg)        98 non-null     float64
# ...

# %% [markdown]
# Here's what the output means:
#
# **fitDataFrame** is a DataFrame object from the pandas library.
#
# The DataFrame has a total of **401 entries (rows)** with a RangeIndex starting from 0 to 400.
#
# There are **26 data columns** in the DataFrame, each representing different metrics or features.
#
# The column names and their respective data types are listed under the "Data columns" section.
#
# For each column, the **"Non-Null Count"** indicates how many non-missing (non-null) values are present.
#
# The "Dtype" column represents the data type of each column.
#
# The "memory usage" shows the approximate memory consumed by the DataFrame.
#
# From this information, we can see that our dataset has __a mix of numerical and non-numeric data.__ We have several columns with missing values, indicated by the difference between the total number of entries (401) and the non-null counts for each column.
#
# Now that we have an overview of our data's structure and missing values, we can move on to exploring and analyzing the data further. 📊🕵️‍♀️

# %%
fitDataFrame.tail()
# Out:
#            Date  Move Minutes count  Calories (kcal)  Distance (m)  \
# 396  2023-07-28                99.0      1563.249975   4764.487783
# 397  2023-07-29                59.0      1581.959861   3136.019941
# 398  2023-07-30                 1.0      1394.250001     24.881966
# 399  2023-07-31                76.0      1628.198926   4651.878158
# 400  2023-08-01                 1.0       916.707601     33.929954
#
#      Heart Points  Heart Minutes  Average heart rate (bpm)  \
# 396          36.0           36.0                       NaN
# 397          28.0           28.0                       NaN
# 398           NaN            NaN                       NaN
# 399          58.0           58.0                       NaN
# 400           NaN            NaN                       NaN
#
#      Max heart rate (bpm)  Min heart rate (bpm)  Low latitude (deg)  ...  \
# 396                   NaN                   NaN           13.713904  ...
# ...

# %% [markdown]
# The output shows the last five rows of the fitDataFrame, giving us a glimpse of the most recent data. Here's what each column represents:
#
# __Date__: The date of the recorded activity metrics.
#
# __Move Minutes count__: The number of minutes with movement detected.
#
# __Calories (kcal)__: The number of calories burned during the recorded activity.
#
# __Distance (m)__: The distance covered in meters during the activity.
#
# __Heart Points__: Points earned based on heart rate activity.
#
# __Heart Minutes__: The number of minutes with heart rate activity.
#
# __Average heart rate (bpm)__: The average heart rate in beats per minute.
#
# __Max heart rate (bpm)__: The maximum heart rate recorded in beats per minute.
#
# __Min heart rate (bpm)__: The minimum heart rate recorded in beats per minute.
#
# __Low latitude (deg) and Low longitude (deg)__: Latitude and longitude coordinates for the lowest location.
#
# __High latitude (deg) and High longitude (deg)__: Latitude and longitude coordinates for the highest location.
#
# __Average speed (m/s)__: The average speed during the activity in meters per second.
#
# __Max speed (m/s)__: The maximum speed recorded during the activity in meters per second.
#
# __Min speed (m/s)__: The minimum speed recorded during the activity in meters per second.
#
# __Step count__: The number of steps taken during the activity.
#
# __Average weight (kg), Max weight (kg), and Min weight (kg)__: Weight-related metrics, related to body weight.
#
# __Biking duration (ms), Inactive duration (ms), Walking duration (ms), Running duration (ms), Calisthenics duration (ms), and Other duration (ms)__: Durations in milliseconds for specific activities.
#
# Remember that some columns may have missing values (NaN) since not all metrics are recorded for every date. This tail view helps us quickly assess the most recent data in our DataFrame.🕵️‍♂️📈

# %%
fitDataFrame.drop(['Average heart rate (bpm)','Max heart rate (bpm)','Min heart rate (bpm)','Low latitude (deg)','Low longitude (deg)','High latitude (deg)','High longitude (deg)',
                   'Max weight (kg)','Average weight (kg)','Min weight (kg)','Biking duration (ms)'],
                  axis=1,inplace=True)
fitDataFrame
# Out:
#            Date  Move Minutes count  Calories (kcal)  Distance (m)  \
# 0    2021-10-19                 9.0       152.299999           NaN
# 1    2021-10-20                15.0       206.899996           NaN
# 2    2021-10-21                 8.0       163.000000           NaN
# 3    2021-10-25                10.0       146.699994           NaN
# 4    2021-10-26               392.0        87.599998           NaN
# ..          ...                 ...              ...           ...
# 396  2023-07-28                99.0      1563.249975   4764.487783
# 397  2023-07-29                59.0      1581.959861   3136.019941
# 398  2023-07-30                 1.0      1394.250001     24.881966
# 399  2023-07-31                76.0      1628.198926   4651.878158
# 400  2023-08-01                 1.0       916.707601     33.929954
#
#      Heart Points  Heart Minutes  Average speed (m/s)  Max speed (m/s)  \
# 0             9.0            9.0                  NaN              NaN
# ...

# %% [markdown]
# #### Cleaning the Data for Insightful Analysis
#
# Before we embark on our data analysis adventure, it's essential to tidy up the data and make it squeaky clean! Data cleaning is like decluttering our dataset and keeping only what matters most for our research. We want our data to be meaningful, relevant, and free from unnecessary noise.
#
# As we examined the data info, we noticed that some columns, such as Average,Max and Min Heart rate are empty and lack any valuable information. Since our focus is not on geographical data, we can safely bid farewell to columns with latitude and longitude information. By cleaning our data and stripping away irrelevant elements, we're setting the stage for an insightful analysis that will bring out the true essence of our dataset.📊🧹

# %%
fitDataFrame.fillna(0, inplace=True)
fitDataFrame
# Out:
#            Date  Move Minutes count  Calories (kcal)  Distance (m)  \
# 0    2021-10-19                 9.0       152.299999      0.000000
# 1    2021-10-20                15.0       206.899996      0.000000
# 2    2021-10-21                 8.0       163.000000      0.000000
# 3    2021-10-25                10.0       146.699994      0.000000
# 4    2021-10-26               392.0        87.599998      0.000000
# ..          ...                 ...              ...           ...
# 396  2023-07-28                99.0      1563.249975   4764.487783
# 397  2023-07-29                59.0      1581.959861   3136.019941
# 398  2023-07-30                 1.0      1394.250001     24.881966
# 399  2023-07-31                76.0      1628.198926   4651.878158
# 400  2023-08-01                 1.0       916.707601     33.929954
#
#      Heart Points  Heart Minutes  Average speed (m/s)  Max speed (m/s)  \
# 0             9.0            9.0             0.000000         0.000000
# ...

# %% [markdown]
# We've filled any missing values (NaN) in the fitDataFrame with zeros. Let's review the changes made by the fillna() method and the overall effect on the DataFrame:
#
# Here's a breakdown of what we've done:
#
# **fillna(0)**: The fillna() method is used to fill missing values in a DataFrame with specified values. In this case, we've used fillna(0) to replace any NaN (missing) values with zeros.
#
# **inplace=True**: As before, inplace=True means the fill operation is applied directly to the original DataFrame, modifying it in place.
#
# By filling missing values with zeros, we've effectively plugged the gaps in our data. This can be useful when missing values are not appropriate for our analysis and we prefer to assign a specific value (in this case, zero) in their place.
#
# Now, our fitDataFrame is clean, complete, and ready for further exploration and analysis! With no more missing values to worry about. 🚀🔍

# %%
fitDataFrame.describe()
# Out:
#        Move Minutes count  Calories (kcal)  Distance (m)  Heart Points  \
# count          401.000000       401.000000    401.000000    401.000000
# mean            35.788030      1441.384072   1413.356217     13.007481
# std             53.009692       280.050073   2004.353075     25.757571
# min              0.000000         0.000000      0.000000      0.000000
# 25%              1.000000      1394.250001     21.488971      0.000000
# 50%             13.000000      1432.553801    153.250295      2.000000
# 75%             54.000000      1564.453145   2488.215878     20.000000
# max            451.000000      2213.464527   9554.063741    392.000000
#
#        Heart Minutes  Average speed (m/s)  Max speed (m/s)  Min speed (m/s)  \
# count     401.000000           401.000000       401.000000       401.000000
# mean       12.837905             0.421950         1.691777         0.173715
# std        25.479328             0.378187         3.915655         0.142599
# ...

# %% [markdown]
# The describe() method provides statistical summaries for each numerical column in the DataFrame. Here's what each row represents:
#
# **count**: The number of non-missing values in each column.
#
# **mean**: The average (mean) value of each column.
#
# **std**: The standard deviation, which measures the spread or variability of the data.
#
# **min**: The minimum value in each column.
#
# **25%**: The first quartile or 25th percentile value.
#
# **50%**: The second quartile or median value.
#
# **75%**: The third quartile or 75th percentile value.
#
# **max**: The maximum value in each column.
#
# These summary statistics offer valuable insights into the distribution and variation of the data. For instance, we can see the average number of move minutes, calories burned, distance covered, heart points earned, heart minutes, and various other metrics recorded in our Google Fit data.
#
# With this overview, we can quickly identify the range of values, potential outliers, and patterns in the data, which can guide our further exploration and analysis.🚀📊

# %%
plt.figure(figsize=(10, 6))

# Line plot of Step count by Year
sns.lineplot(x='Year', y='Step count', data=yearly_data)
plt.title('Step Count by Year')
plt.xlabel('Year')
plt.ylabel('Step Count')
plt.xticks(yearly_data['Year'])  # Ensure all years are shown on the x-axis
plt.show()

# %% [markdown]
# From the output figure, visualizing the data first with the full date is overwhelming, especially if you have a large dataset with many different dates. But fear not! We've got a brilliant plan to bring clarity to our analysis.
#
# Let's start by focusing on a yearly comparison of our fitness metrics. By extracting the year from the 'Date' column, we can aggregate the data and get a clearer picture of the overall trends in your fitness journey. This approach allows us to spot patterns and identify how your fitness activities have evolved over the years.

# %%
fitDataFrame['Year'] = pd.to_datetime(fitDataFrame['Date']).dt.year
yearly_data = fitDataFrame.groupby('Year').agg({
    'Move Minutes count': 'sum',
    'Calories (kcal)': 'sum',
    'Distance (m)': 'sum',
    'Step count': 'sum',
    # Add other relevant columns for aggregation if needed
}).reset_index()
plt.figure(figsize=(10, 6))

# Example: Bar plot of Move Minutes count by Year
sns.barplot(x='Year', y='Move Minutes count', data=yearly_data)
plt.title('Move Minutes Count by Year')
plt.xlabel('Year')
plt.ylabel('Move Minutes Count')
plt.show()

# %% [markdown]
# **Based on the unleashed magic of data visualization , we now grasp the bigger picture of my fitness achievements. In 2021, my moving minutes count danced around 1000, but in 2022, it soared to 4000, and 2023 (till July) brought an astonishing 10000! The graph is a testament to my growth, resilience, and determination. Embrace this revelation and stride boldly towards a healthier, stronger future! 🚀📊💪**

# %%
# Step 1: Extract Month from Date
fitDataFrame['Month'] = pd.to_datetime(fitDataFrame['Date']).dt.month

# Step 2: Group Data by Month in 2023
active_month_2023 = fitDataFrame[fitDataFrame['Year'] == 2023].groupby('Month').agg({
    'Move Minutes count': 'sum',
    'Calories (kcal)': 'sum',
    'Distance (m)': 'sum',
    'Step count': 'sum',
    # Add other relevant columns for aggregation if needed
}).reset_index()

# Step 3: Data Visualization with Custom X-axis Labels
plt.figure(figsize=(10, 6))

# Bar plot of Move Minutes count by Month in 2023
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sns.barplot(x='Month', y='Move Minutes count', data=active_month_2023)
plt.title('Most Active Month in 2023')
plt.xlabel('Month')
plt.ylabel('Move Minutes Count')
plt.xticks(range(0,12), month_names)  # Customizing x-axis labels
plt.show()

# %% [markdown]
# #### A Month-by-Month Adventure: Unraveling My Fitness Journey
#
# 2023 has been a year of energy and action, and I couldn't be more thrilled! Eager to explore my fitness data month by month, I dived into the past to uncover my most active periods. What a ride it turned out to be!
#
# As the data unfolded, I saw a captivating bar plot come to life. Each bar represented a month in 2023, and the height of the bar revealed my 'Move Minutes count' - a powerful metric capturing my active minutes.
#
# **January** - A Roaring Start: The year began with a burst of enthusiasm, and January witnessed my most active days, soaring to a dazzling 2500 minutes of movement. What a way to kickstart the year with vigor!
#
# **April and July** - Peaks of Power: Spring and summer brought their own magic, as April and July shone with around 2000 active minutes each. Those months felt like a triumphant dance of dedication and determination.
#
# **February, May, and June** - Embracing Growth: While February, May, and June saw fewer active minutes, they were essential parts of my journey. These months taught me the value of embracing growth and acknowledging that progress comes in many forms.
#
# As I gazed at the graph, I felt a wave of inspiration and gratitude. It was a reminder that consistency is key and every month contributes to the bigger picture of my fitness adventure.
#
# Armed with this knowledge, I look ahead with excitement, ready to conquer the months to come. 2023 is a year of action, and I am determined to be consistent in my quest for a healthier, happier me.
#
# So, here's to the thrill of a month-by-month breakdown, a roadmap to my fitness achievements. Let each step be filled with movement and each month be a masterpiece of progress. Here's to embracing the journey and living life to the fullest, one active moment at a time! 🚀📊💪

# %%
# Step 1: Extract Month from Date
fitDataFrame['Month'] = pd.to_datetime(fitDataFrame['Date']).dt.month

# Step 2: Extract Weekday from Date
fitDataFrame['Weekday'] = pd.to_datetime(fitDataFrame['Date']).dt.weekday

# Step 3: Filter Data for July 2023
july_data = fitDataFrame[(fitDataFrame['Year'] == 2023) & (fitDataFrame['Month'] == 7)]

# Step 4: Group Data by Weekday
weekly_activity = july_data.groupby('Weekday').agg({
    'Move Minutes count': 'sum',
}).reset_index()

# Step 5: Data Visualization
plt.figure(figsize=(12, 6))

# Customize the Seaborn style and palette
sns.set_theme(style="whitegrid", palette="muted")

# Bar plot of Weekly Activity
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sns.barplot(x='Weekday', y='Move Minutes count', data=weekly_activity, palette="rocket")

# Customize plot aesthetics
plt.title('Weekly Activity in July 2023', fontsize=18, fontweight='bold')
plt.xlabel('Day of the Week', fontsize=14)
plt.ylabel('Move Minutes Count', fontsize=14)
plt.xticks(range(7), days, fontsize=12)
plt.yticks(fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ### Unraveling the Enchanting Mysteries of My Fitness Journey
#
# Intrigued by the secrets hidden within my fitness data, I embarked on a captivating data deep dive into the enchanting realm of July 2023. Armed with the power of data visualization, I yearned to unlock the wonders of my weekly activity and uncover the peaks and valleys of each day
#
# Oh dear, I hit a tiny roadblock on my quest to explore daily activity patterns. Unfortunately, the time data was nowhere to be found, and I was left with only the days of the week to investigate. But hey, I wasn't about to let that bring me down! My spirits were still high and soaring! 🚀I delved into the available data, eager to unravel the magic of my fitness rhythms.
#
# The graph revealed fascinating insights. A pattern emerged, portraying my activeness throughout the week. Mondays were the stars of the show, filled with energy and movement. But as the week progressed, my activity tapered down, reaching its lowest on serene Sundays.
#
# Ah, such a typical me, I couldn't help but laugh! As a self-proclaimed "potato coach girl," I realized I had a tendency to indulge in cozy weekends, binging on Netflix and chips. It was time for a gentle nudge to break the pattern and embrace more adventurous outings.
#
# The data spoke to me, nudging me to step out of my comfort zone and make the most of weekends. So, with renewed determination, I pledged to transform my lazy Sundays into vibrant, activity-filled days.
#
# As I gazed at the graph, a wave of motivation washed over me. Armed with these newfound insights, I felt empowered to craft a fitness routine that harmonized with my natural rhythms.
#
# With each passing day, I vow to embrace my fitness journey with excitement and joy. The mysteries of my fitness data have ignited a spark within me, propelling me towards a healthier, happier me.
#
# So, here's to the enchanting dance of fitness rhythms, a journey of self-discovery and growth. I'll cherish my active Mondays and embrace the challenge to make every day shine bright like a star. It's time to break free from the couch and embark on adventures that fuel my body and soul! 🚀📊💪
